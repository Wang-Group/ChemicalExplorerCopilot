# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs20241201.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_26_CuAspirin\materials_output_20241129172208537956.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_26_CuAspirin\output_20241129172208537956.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['Aspirin']
# after conversion:
# ['Aspirin']
# before conversion:
# ['Methanol']
# after conversion:
# ['methanol', 'Methanol']
# before conversion:
# ['Cu(OAc)2·H2O']
# after conversion:
# ['Cu(OAc)2.H2O', 'Cu(OAc)2·H2O']
# before conversion:
# ['Water']
# after conversion:
# ['H2O', 'Water']
# before conversion:
# ['Ethanol']
# after conversion:
# ['ethanol', 'Ethanol']
# before conversion:
# ['Water']
# after conversion:
# ['H2O', 'Water']
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 1.8 g
# after conversion:
# 1.8 g
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 15.0 mL
# after conversion:
# 15.0 mL
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 1.5 g
# after conversion:
# 1.5 g
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 20.0 mL
# after conversion:
# 20.0 mL
# ####################################################################################################
# Function: TransferLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AdjustTemperatureTo
# Property: temperature
# before conversion:
# temperature 25.0 ℃
# after conversion:
# 25.0 °C
# ####################################################################################################
# Function: AdjustTemperatureTo
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: Wait
# Property: time
# before conversion:
# time 40.0 minutes
# after conversion:
# 2400.0 second
# ####################################################################################################
# Function: Filter
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Dry
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Yield
# Property: product_quantity
# before conversion:
# product_quantity 1.94 g
# after conversion:
# 1.94 g
# ####################################################################################################
# Function: Yield
# Property: yield_percentage
# before conversion:
# yield_percentage 92.0 %
# after conversion:
# 92.0 %
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Aspirin"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 1.8,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "methanol",
#                     "Methanol"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 15.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "separate container",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Cu(OAc)2.H2O",
#                     "Cu(OAc)2\u00b7H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 1.5,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "separate container",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "Water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 20.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "TransferLiquid",
#     "function_args": {
#         "from_reactor": "separate container",
#         "to_reactor": "100mL three-necked flask",
#         "volume": "all",
#         "dropwise": true,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "temperature": {
#             "quantity": 25.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Wait",
#     "function_args": {
#         "time": {
#             "quantity": 2400.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "target_form": "solid",
#         "filtrate_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "WashSolid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "solvent": {
#             "identity": {
#                 "chemical_id": [
#                     "ethanol",
#                     "Ethanol"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "solvent_temperature": null,
#         "volume": "appropriate",
#         "waste_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "atmosphere": "air",
#         "repeat": 1
#     }
# }
# Warning: there is ambiguity in the definition of volume.
# Its current value is <appropriate>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# volume
# before conversion:
# volume 10.0 mL
# after conversion:
# 10.0 mL
# None
# ####################################################################################################
# {
#     "function_name": "WashSolid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "solvent": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "Water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "solvent_temperature": null,
#         "volume": "appropriate",
#         "waste_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "atmosphere": "air",
#         "repeat": 1
#     }
# }
# Warning: there is ambiguity in the definition of volume.
# Its current value is <appropriate>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# volume
# before conversion:
# volume 10.0 mL
# after conversion:
# 10.0 mL
# None
# ####################################################################################################
# {
#     "function_name": "Dry",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "time": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# Warning: there is ambiguity in the definition of time.
# Its current value is <None>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# time
# before conversion:
# time 10.0 min
# after conversion:
# 600.0 second
# None
# ####################################################################################################
# {
#     "function_name": "Yield",
#     "function_args": {
#         "product_name": "blue powder",
#         "product_quantity": {
#             "quantity": 1.94,
#             "unit": "g"
#         },
#         "yield_percentage": {
#             "quantity": 92.0,
#             "unit": "%"
#         }
#     }
# }
# None
# ****************************************************************************************************
# Ambiguity check trial 1
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Aspirin"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 1.8,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "methanol",
#                     "Methanol"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 15.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "separate container",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Cu(OAc)2.H2O",
#                     "Cu(OAc)2\u00b7H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 1.5,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "separate container",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "Water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 20.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "TransferLiquid",
#     "function_args": {
#         "from_reactor": "separate container",
#         "to_reactor": "100mL three-necked flask",
#         "volume": "all",
#         "dropwise": true,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "temperature": {
#             "quantity": 25.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Wait",
#     "function_args": {
#         "time": {
#             "quantity": 2400.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "target_form": "solid",
#         "filtrate_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "WashSolid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "solvent": {
#             "identity": {
#                 "chemical_id": [
#                     "ethanol",
#                     "Ethanol"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "solvent_temperature": null,
#         "volume": "appropriate",
#         "waste_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "atmosphere": "air",
#         "repeat": 1
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "WashSolid",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "solvent": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "Water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "solvent_temperature": null,
#         "volume": "appropriate",
#         "waste_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "atmosphere": "air",
#         "repeat": 1
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Dry",
#     "function_args": {
#         "reactor_name": "100mL three-necked flask",
#         "time": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Yield",
#     "function_args": {
#         "product_name": "blue powder",
#         "product_quantity": {
#             "quantity": 1.94,
#             "unit": "g"
#         },
#         "yield_percentage": {
#             "quantity": 92.0,
#             "unit": "%"
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001D37FBC0B50>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001D37FBC0D50>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001D37FBC1010>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001D37FBC12D0>
# <llmlab.operations.exp_operation.transfer.TransferLiquid object at 0x000001D37FBC1490>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureTo object at 0x000001D37FBC1110>
# <llmlab.operations.exp_operation.wait.Wait object at 0x000001D37FBC1A50>
# <llmlab.operations.exp_operation.filtration.Filter object at 0x000001D37FBC1B90>
# <llmlab.operations.exp_operation.washsolid.WashSolid object at 0x000001D37FBC1D10>
# <llmlab.operations.exp_operation.washsolid.WashSolid object at 0x000001D37FBC14D0>
# <llmlab.operations.exp_operation.washsolid.Dry object at 0x000001D37FBE8E50>
# <llmlab.operations.exp_operation.yield_.Yield object at 0x000001D37FBE8F90>
# rescaling the system: rescale_factor is 0.2857142857142857
# ['100mL three-necked flask', 'separate container', 'waste']

# %%
manager.perform_exp()
# Out:
# task: AddSolid start, now time is 2024-12-01 17:32:01.950159
# task: AddSolid over, now time is 2024-12-01 17:37:39.229991
# task: AddLiquid start, now time is 2024-12-01 17:37:39.229991
# task: AddLiquid over, now time is 2024-12-01 17:52:47.685627
# task: AddSolid start, now time is 2024-12-01 17:52:47.685627
# task: AddSolid over, now time is 2024-12-01 17:58:29.090605
# task: AddLiquid start, now time is 2024-12-01 17:58:29.090605
# task: AddLiquid over, now time is 2024-12-01 18:13:48.429970
# task: TrasnferLiquid start, now time is 2024-12-01 18:13:48.429970
# task: TrasnferLiquid over, now time is 2024-12-01 18:20:53.479838
# task: AdjustTemperatureTo start, now time is 2024-12-01 18:20:53.479838
# task: AdjustTemperatureTo over, now time is 2024-12-01 18:31:53.071913
# task: Wait start, now time is 2024-12-01 18:31:53.071913
# task: Wait over, now time is 2024-12-01 19:11:53.072321
# task: Filter start, now time is 2024-12-01 19:11:53.072321
# task: Filter over, now time is 2024-12-01 20:16:50.351819
# task: WashSolid start, now time is 2024-12-01 20:16:50.351819
# task: WashSolid over, now time is 2024-12-01 20:48:38.344292
# task: WashSolid start, now time is 2024-12-01 20:48:38.344292
# task: WashSolid over, now time is 2024-12-01 21:20:27.567599
# task: Dry start, now time is 2024-12-01 21:20:27.567599
# task: Dry over, now time is 2024-12-01 21:30:27.568563
