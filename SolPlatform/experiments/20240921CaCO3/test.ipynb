# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_1\materials_output_20240730133435236526 copy.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_1\output_20240730133435236526.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
# Out:
# before conversion:
# ['CaCl2', 'calcium chloride solution']
# after conversion:
# ['CaCl2', 'calcium chloride solution']
# before conversion:
# ['Na2CO3', 'sodium carbonate solution']
# after conversion:
# ['Na2CO3', 'sodium carbonate solution']
# ####################################################################################################
# ['CaCl2', 'calcium chloride solution']
# before conversion:
# concentration 0.1 mol/L
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 5.0 mL
# after conversion:
# 5.0 mL
# ####################################################################################################
# ['Na2CO3', 'sodium carbonate solution']
# before conversion:
# concentration 0.1 mol/L
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 5.0 mL
# after conversion:
# 5.0 mL
# ####################################################################################################
# Function: TransferLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: StirForDuration
# Property: duration
# before conversion:
# duration 300.0 second
# after conversion:
# 300.0 second
# ####################################################################################################
# Function: StirForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['CaCl2']
# before conversion:
# concentration 0.2 mol/L
# after conversion:
# 0.2 mol/L
# ####################################################################################################
# ['Na2CO3']
# before conversion:
# concentration 0.1 mol/L
# after conversion:
# 0.1 mol/L
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor0",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "CaCl2",
#                     "calcium chloride solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 5.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2CO3",
#                     "sodium carbonate solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 5.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "TransferLiquid",
#     "function_args": {
#         "from_reactor": "reactor1",
#         "to_reactor": "reactor0",
#         "volume": "all",
#         "dropwise": false,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "reactor0",
#         "temperature": null,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 300.0,
#             "unit": "second"
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024784049050>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024784049310>
# <llmlab.operations.exp_operation.transfer.TransferLiquid object at 0x0000024784049510>
# <llmlab.operations.exp_operation.stir.StirForDuration object at 0x00000247840498D0>
# []

# %%
manager.perform_exp()
# Out:
# task: AddLiquid start, now time is 2024-10-01 21:01:03.786242
# task: AddLiquid over, now time is 2024-10-01 21:03:58.011478
# task: AddLiquid start, now time is 2024-10-01 21:03:58.011478
# task: AddLiquid over, now time is 2024-10-01 21:07:43.922080
# task: TrasnferLiquid start, now time is 2024-10-01 21:07:43.922080
# task: TrasnferLiquid over, now time is 2024-10-01 21:11:30.192420
# task: StirForDuration start, now time is 2024-10-01 21:11:30.192420
# task: StirForDuration over, now time is 2024-10-01 21:22:24.859245
# Exception in thread COM26:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\users\admin\documents\github\platform_manager\commanduino\commanduino\commandhandler.py", line 369, in run
# Exception in thread COM10:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\users\admin\documents\github\platform_manager\commanduino\commanduino\commandhandler.py", line 369, in run
#     raise CMTimeout(f"Error reading from serial port {self._serial.port}! {e}") from None
# commanduino.exceptions.CMTimeout: Error reading from serial port COM10! ClearCommError failed (PermissionError(13, 'The device does not recognize the command.', None, 22))
#     raise CMTimeout(f"Error reading from serial port {self._serial.port}! {e}") from None
# commanduino.exceptions.CMTimeout: Error reading from serial port COM26! ClearCommError failed (PermissionError(13, 'The device does not recognize the command.', None, 22))
