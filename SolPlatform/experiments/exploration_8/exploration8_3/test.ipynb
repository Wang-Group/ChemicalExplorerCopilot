# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs_20241218.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\exp_63_exploration_8_3\materials_output_20241209132311455788_template3.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\exp_63_exploration_8_3\output_20241209132311455788_template3.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['deionized water']
# after conversion:
# ['H2O', 'deionized water']
# before conversion:
# ['sol.Mn']
# after conversion:
# ['sol.Mn']
# before conversion:
# ['Na₂WO₄ stock solution']
# after conversion:
# ['Na2WO4.2H2O', 'Na₂WO₄ stock solution']
# before conversion:
# ['Gd(ClO₄)₃ solution']
# after conversion:
# ['Gd(ClO4)3', 'Gd(ClO₄)₃ solution']
# before conversion:
# ['Na₂WO₄ stock solution']
# after conversion:
# ['Na2WO4.2H2O', 'Na₂WO₄ stock solution']
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 8.9 mL
# after conversion:
# 8.9 mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 1.1 mL
# after conversion:
# 1.1 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: StirForDuration
# Property: duration
# before conversion:
# duration 15.0 seconds
# after conversion:
# 15.0 second
# ####################################################################################################
# Function: StirForDuration
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: StirForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['Na₂WO₄ stock solution', 'Na2WO4.2H2O']
# before conversion:
# concentration 0.15 g/mL
# after conversion:
# 0.15 g/mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 4.25 mL
# after conversion:
# 4.25 mL
# ####################################################################################################
# ['Gd(ClO₄)₃ solution', 'Gd(ClO4)3']
# before conversion:
# concentration 1.0 M
# after conversion:
# 1.0 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.5 mL
# after conversion:
# 0.5 mL
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 76.44 ℃
# after conversion:
# 76.44 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 17.02 minutes
# after conversion:
# 1021.1999999999999 second
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['Na₂WO₄ stock solution', 'Na2WO4.2H2O']
# before conversion:
# concentration 0.15 g/mL
# after conversion:
# 0.15 g/mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 13.66 mL
# after conversion:
# 13.66 mL
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 90.0 ℃
# after conversion:
# 90.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 30.0 minutes
# after conversion:
# 1800.0 second
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AdjustTemperatureTo
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Filter
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Evaporate
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Evaporate
# Property: duration
# before conversion:
# duration 2.0 weeks
# after conversion:
# 1209600.0 second
# ####################################################################################################
# Function: Evaporate
# Property: duration
# before conversion:
# duration 4.0 weeks
# after conversion:
# 2419200.0 second
# ####################################################################################################
# ['Na2WO4.2H2O']
# before conversion:
# concentration 0.15 g/mL
# after conversion:
# 0.15 g/mL
# ####################################################################################################
# ['Gd(ClO4)3']
# before conversion:
# concentration 1.0 M
# after conversion:
# 1.0 mol/L
# ####################################################################################################
# ['acetic acid']
# before conversion:
# concentration 0.5 M
# after conversion:
# 0.5 mol/L
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "deionized water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 8.9,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "sol.Mn"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 1.1,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 15.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2WO4.2H2O",
#                     "Na\u2082WO\u2084 stock solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.15,
#                 "unit": "g/mL"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 4.25,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Gd(ClO4)3",
#                     "Gd(ClO\u2084)\u2083 solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 1.0,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.5,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 76.44,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 1021.1999999999999,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2WO4.2H2O",
#                     "Na\u2082WO\u2084 stock solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.15,
#                 "unit": "g/mL"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 13.66,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 90.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 1800.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "target_form": "liquid",
#         "filtrate_vessel": "clean container",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Evaporate",
#     "function_args": {
#         "reactor_name": "clean container",
#         "pressure": null,
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "min": {
#                 "quantity": 1209600.0,
#                 "unit": "second"
#             },
#             "max": {
#                 "quantity": 2419200.0,
#                 "unit": "second"
#             }
#         }
#     }
# }
# Warning: there is ambiguity in the definition of duration.
# Its current value is <{'min': Property(quantity=1209600.0, unit='second'), 'max': Property(quantity=2419200.0, unit='second')}>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# duration
# before conversion:
# duration 2.0 week
# after conversion:
# 1209600.0 second
# None
# ****************************************************************************************************
# Ambiguity check trial 1
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "deionized water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 8.9,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "sol.Mn"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 1.1,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 15.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2WO4.2H2O",
#                     "Na\u2082WO\u2084 stock solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.15,
#                 "unit": "g/mL"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 4.25,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Gd(ClO4)3",
#                     "Gd(ClO\u2084)\u2083 solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 1.0,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.5,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 76.44,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 1021.1999999999999,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2WO4.2H2O",
#                     "Na\u2082WO\u2084 stock solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.15,
#                 "unit": "g/mL"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 13.66,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 90.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 1800.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "target_form": "liquid",
#         "filtrate_vessel": "clean container",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Evaporate",
#     "function_args": {
#         "reactor_name": "clean container",
#         "pressure": null,
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "min": {
#                 "quantity": 1209600.0,
#                 "unit": "second"
#             },
#             "max": {
#                 "quantity": 2419200.0,
#                 "unit": "second"
#             }
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000029BFD4E9610>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000029BFD4E98D0>
# <llmlab.operations.exp_operation.stir.StirForDuration object at 0x0000029BFD4E9BD0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000029BFD4E9E10>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000029BFD4E9F90>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x0000029BFD4EA1D0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000029BFD4EA690>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x0000029BFD4EA590>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureTo object at 0x0000029BFD4EAAD0>
# <llmlab.operations.exp_operation.filtration.Filter object at 0x0000029BFD4EABD0>
# <llmlab.operations.exp_operation.evaporate.Evaporate object at 0x0000029BFD4EAC90>
# rescaling the system: rescale_factor is 0.3519887363604364
# ['50 mL beaker', 'clean container']

# %%
manager.perform_exp()
# Out:
# task: AddLiquid start, now time is 2024-12-18 13:43:26.083855
# task: AddLiquid over, now time is 2024-12-18 13:48:55.040479
# task: AddLiquid start, now time is 2024-12-18 13:48:55.040479
# task: AddLiquid over, now time is 2024-12-18 13:50:08.352344
# task: StirForDuration start, now time is 2024-12-18 13:50:08.352344
# task: StirForDuration over, now time is 2024-12-18 13:50:56.364116
# task: AddLiquid start, now time is 2024-12-18 13:50:56.364116
# task: AddLiquid over, now time is 2024-12-18 13:52:16.794423
# task: AddLiquid start, now time is 2024-12-18 13:52:16.794423
# task: AddLiquid over, now time is 2024-12-18 13:53:12.267993
# task: AdjustTemperatureForDuration start, now time is 2024-12-18 13:53:12.267993
# task: AdjustTemperatureForDuration over, now time is 2024-12-18 14:21:55.343325
# task: AddLiquid start, now time is 2024-12-18 14:21:55.343325
# task: AddLiquid over, now time is 2024-12-18 14:25:29.672736
# task: AdjustTemperatureForDuration start, now time is 2024-12-18 14:25:29.672736
# task: AdjustTemperatureForDuration over, now time is 2024-12-18 15:06:20.315012
# task: AdjustTemperatureTo start, now time is 2024-12-18 15:06:20.315012
# task: AdjustTemperatureTo over, now time is 2024-12-18 15:16:20.315307
# task: Filter start, now time is 2024-12-18 15:16:20.315307
# task: Filter over, now time is 2024-12-18 16:25:45.640087
# task: Evaporate start, now time is 2024-12-18 16:25:45.640087
# email sent success
# task: Evaporate over, now time is 2024-12-18 16:25:47.912127
