# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs_20241118.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\exp_45_exploration_4_0\materials_output_20241104131931508754_template0.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\exp_45_exploration_4_0\output_20241104131931508754_template0.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
# Out:
# before conversion:
# ['deionized water']
# after conversion:
# ['H2O', 'deionized water']
# before conversion:
# ['sol.Mn']
# after conversion:
# ['sol.Mn']
# before conversion:
# ['Na₂WO₄ stock solution']
# after conversion:
# ['Na2WO4.2H2O', 'Na₂WO₄ stock solution']
# before conversion:
# ['boric acid (H₃BO₃)']
# after conversion:
# ['H3BO3', 'boric acid (H₃BO₃)']
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 8.9 mL
# after conversion:
# 8.9 mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 1.1 mL
# after conversion:
# 1.1 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: StirForDuration
# Property: duration
# before conversion:
# duration 30.0 seconds
# after conversion:
# 30.0 second
# ####################################################################################################
# Function: StirForDuration
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: StirForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['Na₂WO₄ stock solution', 'Na2WO4.2H2O']
# before conversion:
# concentration 0.4 g/mL
# after conversion:
# 0.4 g/mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 5.79 mL
# after conversion:
# 5.79 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 0.69 g
# after conversion:
# 0.69 g
# ####################################################################################################
# Function: AddSolid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 90.0 ℃
# after conversion:
# 90.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 1.0 hour
# after conversion:
# 3600.0 second
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AdjustTemperatureTo
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Filter
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Evaporate
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Evaporate
# Property: duration
# before conversion:
# duration 1.0 week
# after conversion:
# 604800.0 second
# ####################################################################################################
# Function: Evaporate
# Property: duration
# before conversion:
# duration 2.0 weeks
# after conversion:
# 1209600.0 second
# ####################################################################################################
# ['Na2WO4.2H2O']
# before conversion:
# concentration 0.4 g/mL
# after conversion:
# 0.4 g/mL
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "deionized water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 8.9,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "sol.Mn"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 1.1,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 30.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2WO4.2H2O",
#                     "Na\u2082WO\u2084 stock solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.4,
#                 "unit": "g/mL"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 5.79,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "H3BO3",
#                     "boric acid (H\u2083BO\u2083)"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.69,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 90.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 3600.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "target_form": "liquid",
#         "filtrate_vessel": "clean container",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Evaporate",
#     "function_args": {
#         "reactor_name": "clean container",
#         "pressure": null,
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "min": {
#                 "quantity": 604800.0,
#                 "unit": "second"
#             },
#             "max": {
#                 "quantity": 1209600.0,
#                 "unit": "second"
#             }
#         }
#     }
# }
# Warning: there is ambiguity in the definition of duration.
# Its current value is <{'min': Property(quantity=604800.0, unit='second'), 'max': Property(quantity=1209600.0, unit='second')}>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# duration
# before conversion:
# duration 1.0 week
# after conversion:
# 604800.0 second
# None
# ****************************************************************************************************
# Ambiguity check trial 1
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "deionized water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 8.9,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "sol.Mn"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 1.1,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 30.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2WO4.2H2O",
#                     "Na\u2082WO\u2084 stock solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.4,
#                 "unit": "g/mL"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 5.79,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "H3BO3",
#                     "boric acid (H\u2083BO\u2083)"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.69,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 90.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 3600.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "50 mL beaker",
#         "target_form": "liquid",
#         "filtrate_vessel": "clean container",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Evaporate",
#     "function_args": {
#         "reactor_name": "clean container",
#         "pressure": null,
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "min": {
#                 "quantity": 604800.0,
#                 "unit": "second"
#             },
#             "max": {
#                 "quantity": 1209600.0,
#                 "unit": "second"
#             }
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x00000169CF8E1490>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x00000169CF8E12D0>
# <llmlab.operations.exp_operation.stir.StirForDuration object at 0x00000169CF8EC6D0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x00000169CF8EC910>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x00000169CF8ECB10>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x00000169CF8ECD90>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureTo object at 0x00000169CF8ED110>
# <llmlab.operations.exp_operation.filtration.Filter object at 0x00000169CF8ED210>
# <llmlab.operations.exp_operation.evaporate.Evaporate object at 0x00000169CF8ED2D0>
# rescaling the system: rescale_factor is 0.6333122229259025
# ['50 mL beaker', 'clean container']

# %%
manager.perform_exp()
# Out:
# task: AddLiquid start, now time is 2024-11-18 20:19:23.777748
# task: AddLiquid over, now time is 2024-11-18 20:25:03.597510
# task: AddLiquid start, now time is 2024-11-18 20:25:03.597510
# task: AddLiquid over, now time is 2024-11-18 20:26:17.542699
# task: StirForDuration start, now time is 2024-11-18 20:26:17.542699
# task: StirForDuration over, now time is 2024-11-18 20:27:20.678680
# task: AddLiquid start, now time is 2024-11-18 20:27:20.678680
# task: AddLiquid over, now time is 2024-11-18 20:29:30.048521
# task: AddSolid start, now time is 2024-11-18 20:29:30.048521
# task: AddSolid over, now time is 2024-11-18 20:34:21.259700
# task: AdjustTemperatureForDuration start, now time is 2024-11-18 20:34:21.259700
# task: AdjustTemperatureForDuration over, now time is 2024-11-18 21:45:51.869038
# task: AdjustTemperatureTo start, now time is 2024-11-18 21:45:51.869038
# task: AdjustTemperatureTo over, now time is 2024-11-18 21:55:51.870208
# task: Filter start, now time is 2024-11-18 21:55:51.870208
# task: Filter over, now time is 2024-11-18 23:05:07.796740
# task: Evaporate start, now time is 2024-11-18 23:05:07.796740
# email sent success
# task: Evaporate over, now time is 2024-11-18 23:05:10.182166
