# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs_20241026.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\exp_8\materials_output_20241021225307848814_copy_paste_swap_sequence_2min.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\exp_8\output_20241021225307848814_copy_paste_swap_sequence_2min.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['CH3COOH']
# after conversion:
# ['CH3COOH']
# before conversion:
# ['Manganese(II) acetate tetrahydrate', 'Mn(CH3COO)2·4H2O']
# after conversion:
# ['Manganese(II) acetate tetrahydrate', 'Mn(CH3COO)2·4H2O']
# before conversion:
# ['KMnO4']
# after conversion:
# ['KMnO4']
# before conversion:
# ['H2O', 'deionized water']
# after conversion:
# ['H2O', 'deionized water']
# before conversion:
# ['Sodium tungstate dihydrate', 'Na2WO4·2H2O']
# after conversion:
# ['Sodium tungstate dihydrate', 'Na2WO4·2H2O']
# ####################################################################################################
# ['CH3COOH']
# before conversion:
# concentration 60.0 %
# after conversion:
# 60.0 %
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 3.333333333333333 mL
# after conversion:
# 3.333333333333333 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 0.3333333333333333 g
# after conversion:
# 0.3333333333333333 g
# ####################################################################################################
# Function: AddSolid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: StirForDuration
# Property: duration
# before conversion:
# duration 600.0 second
# after conversion:
# 600.0 second
# ####################################################################################################
# Function: StirForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 0.08333333333333333 g
# after conversion:
# 0.08333333333333333 g
# ####################################################################################################
# Function: AddSolid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: StirForDuration
# Property: duration
# before conversion:
# duration 3600.0 second
# after conversion:
# 3600.0 second
# ####################################################################################################
# Function: StirForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 2.966666666666667 mL
# after conversion:
# 2.966666666666667 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: TransferLiquid
# Property: volume
# before conversion:
# volume 0.3666666666666667 mL
# after conversion:
# 0.3666666666666667 mL
# ####################################################################################################
# Function: StirForDuration
# Property: duration
# before conversion:
# duration 120.0 second
# after conversion:
# 120.0 second
# ####################################################################################################
# Function: StirForDuration
# Property: temperature
# before conversion:
# temperature 20.0 °C
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: StirForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['Sodium tungstate dihydrate', 'Na2WO4·2H2O']
# before conversion:
# concentration 0.15 g/mL
# after conversion:
# 0.15 g/mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 6.666666666666666 mL
# after conversion:
# 6.666666666666666 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 90.0 °C
# after conversion:
# 90.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 3600.0 second
# after conversion:
# 3600.0 second
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AdjustTemperatureTo
# Property: temperature
# before conversion:
# temperature 20.0 °C
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Filter
# Property: temperature
# before conversion:
# temperature 20.0 °C
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Evaporate
# Property: temperature
# before conversion:
# temperature 20.0 °C
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Evaporate
# Property: duration
# before conversion:
# duration 604800.0 second
# after conversion:
# 604800.0 second
# ####################################################################################################
# ['Sodium tungstate dihydrate']
# before conversion:
# concentration 0.15 g/mL
# after conversion:
# 0.15 g/mL
# ####################################################################################################
# ['CH3COOH']
# before conversion:
# concentration 60.0 %
# after conversion:
# 60.0 %
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor0",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "CH3COOH"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 60.0,
#                 "unit": "%"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 3.333333333333333,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor0",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Manganese(II) acetate tetrahydrate",
#                     "Mn(CH3COO)2\u00b74H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.3333333333333333,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "reactor0",
#         "temperature": null,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 600.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor0",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "KMnO4"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.08333333333333333,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "reactor0",
#         "temperature": null,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 3600.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "deionized water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 2.966666666666667,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "TransferLiquid",
#     "function_args": {
#         "from_reactor": "reactor0",
#         "to_reactor": "reactor1",
#         "volume": {
#             "quantity": 0.3666666666666667,
#             "unit": "mL"
#         },
#         "dropwise": false,
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 120.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "Sodium tungstate dihydrate",
#                     "Na2WO4\u00b72H2O"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.15,
#                 "unit": "g/mL"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 6.666666666666666,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "temperature": {
#             "quantity": 90.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 3600.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "target_form": "liquid",
#         "filtrate_vessel": "reactor2",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Evaporate",
#     "function_args": {
#         "reactor_name": "reactor2",
#         "pressure": null,
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 604800.0,
#             "unit": "second"
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000002195F332690>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000002195F322BD0>
# <llmlab.operations.exp_operation.stir.StirForDuration object at 0x000002195F322B10>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000002195F3228D0>
# <llmlab.operations.exp_operation.stir.StirForDuration object at 0x000002195F332A90>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000002195F332B90>
# <llmlab.operations.exp_operation.transfer.TransferLiquid object at 0x000002195F332DD0>
# <llmlab.operations.exp_operation.stir.StirForDuration object at 0x000002195F3330D0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000002195F333090>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x000002195F332D10>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureTo object at 0x000002195F3336D0>
# <llmlab.operations.exp_operation.filtration.Filter object at 0x000002195F333790>
# <llmlab.operations.exp_operation.evaporate.Evaporate object at 0x000002195F3338D0>
# []

# %%
manager.perform_exp()
# Out:
# task: AddLiquid start, now time is 2024-10-26 14:13:37.410433
# task: AddLiquid over, now time is 2024-10-26 14:16:24.602601
# task: AddSolid start, now time is 2024-10-26 14:16:24.602601
# task: AddSolid over, now time is 2024-10-26 14:32:57.309637
# task: StirForDuration start, now time is 2024-10-26 14:32:57.309637
# task: StirForDuration over, now time is 2024-10-26 14:48:46.322863
# task: AddSolid start, now time is 2024-10-26 14:48:46.322863
# task: AddSolid over, now time is 2024-10-26 15:06:25.670486
# task: StirForDuration start, now time is 2024-10-26 15:06:25.670486
# task: StirForDuration over, now time is 2024-10-26 16:12:15.993904
# task: AddLiquid start, now time is 2024-10-26 16:12:15.993904
# task: AddLiquid over, now time is 2024-10-26 16:14:43.710698
# task: TrasnferLiquid start, now time is 2024-10-26 16:14:43.710698
# task: TrasnferLiquid over, now time is 2024-10-26 16:16:45.343837
# task: StirForDuration start, now time is 2024-10-26 16:16:45.343837
# task: StirForDuration over, now time is 2024-10-26 16:19:13.576143
# task: AddLiquid start, now time is 2024-10-26 16:19:13.576143
# task: AddLiquid over, now time is 2024-10-26 16:24:15.848296
# task: AdjustTemperatureForDuration start, now time is 2024-10-26 16:24:15.848296
# task: AdjustTemperatureForDuration over, now time is 2024-10-26 17:35:52.707643
# task: AdjustTemperatureTo start, now time is 2024-10-26 17:35:52.707643
# task: AdjustTemperatureTo over, now time is 2024-10-26 17:45:52.708702
# task: Filter start, now time is 2024-10-26 17:45:52.708702
# task: Filter over, now time is 2024-10-26 18:55:07.343883
# task: Evaporate start, now time is 2024-10-26 18:55:07.343883
# email sent success
# task: Evaporate over, now time is 2024-10-26 18:55:08.164182
