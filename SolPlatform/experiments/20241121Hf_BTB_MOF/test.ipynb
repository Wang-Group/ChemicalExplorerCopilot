# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_10_MOFs\materials_output_20240909172131320326.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_10_MOFs\output_20240909172131320326.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['HfOCl2·8H2O']
# after conversion:
# ['HfOCl2.8H2O', 'HfOCl2·8H2O']
# before conversion:
# ['H3BTB']
# after conversion:
# ['1,3,5-Tris(4-carboxyphenyl)benzene', 'H3BTB']
# before conversion:
# ['DMF']
# after conversion:
# ['DMF']
# before conversion:
# ['HCOOH']
# after conversion:
# ['HCOOH']
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 61.0 mg
# after conversion:
# 0.061 g
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 65.0 mg
# after conversion:
# 0.065 g
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 7.5 mL
# after conversion:
# 7.5 mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 4.5 mL
# after conversion:
# 4.5 mL
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 120.0 °C
# after conversion:
# 120.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 3.0 days
# after conversion:
# 259200.0 second
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "Teflon-lined autoclave",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "HfOCl2.8H2O",
#                     "HfOCl2\u00b78H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.061,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "Teflon-lined autoclave",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "1,3,5-Tris(4-carboxyphenyl)benzene",
#                     "H3BTB"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.065,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "Teflon-lined autoclave",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "DMF"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 7.5,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "Teflon-lined autoclave",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "HCOOH"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 4.5,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "Teflon-lined autoclave",
#         "temperature": {
#             "quantity": 120.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 259200.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000002109F812990>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000002109F812D90>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000002109F8130D0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000002109F813050>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x000002109F813490>
# rescaling the system: rescale_factor is 0.8333333333333334
# ['Teflon-lined autoclave']

# %%
manager.perform_exp()
# Out:
# task: AddSolid start, now time is 2024-11-21 15:11:12.070832
# task: AddSolid over, now time is 2024-11-21 15:16:31.201598
# task: AddSolid start, now time is 2024-11-21 15:16:31.201598
# task: AddSolid over, now time is 2024-11-21 15:19:28.126387
# task: AddLiquid start, now time is 2024-11-21 15:19:28.126387
# task: AddLiquid over, now time is 2024-11-21 15:34:02.293383
# task: AddLiquid start, now time is 2024-11-21 15:34:02.293383
# task: AddLiquid over, now time is 2024-11-21 15:36:01.073112
# task: AdjustTemperatureForDuration start, now time is 2024-11-21 15:36:01.073112
# task: AdjustTemperatureForDuration over, now time is 2024-11-24 15:47:37.004634
