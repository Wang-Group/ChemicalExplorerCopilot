# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_7\materials_output_20240806104442629270.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_7\output_20240806104442629270.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
# Out:
# before conversion:
# ['HfOCl2.8H2O']
# after conversion:
# ['HfOCl2.8H2O']
# before conversion:
# ['H3BTB']
# after conversion:
# ['1,3,5-Tris(4-carboxyphenyl)benzene', 'H3BTB']
# before conversion:
# ['DMF']
# after conversion:
# ['DMF']
# before conversion:
# ['HCOOH']
# after conversion:
# ['HCOOH']
# before conversion:
# ['water']
# after conversion:
# ['H2O', 'water']
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 17.9 mg
# after conversion:
# 0.0179 g
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 12.5 mg
# after conversion:
# 0.0125 g
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 2.05 mL
# after conversion:
# 2.05 mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.88 mL
# after conversion:
# 0.88 mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.3 mL
# after conversion:
# 0.3 mL
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 120.0 ℃
# after conversion:
# 120.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 2.0 days
# after conversion:
# 172800.0 second
# ####################################################################################################
# Function: Precipitate
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "HfOCl2.8H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.0179,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "1,3,5-Tris(4-carboxyphenyl)benzene",
#                     "H3BTB"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.0125,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "DMF"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 2.05,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "HCOOH"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.88,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.3,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "temperature": {
#             "quantity": 120.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 172800.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Precipitate",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stirring_time": null,
#         "stir_speed": null,
#         "reagent": null,
#         "reagent_quantity": null,
#         "repeat": 1
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 0.0 rpm
# after conversion:
# 0.0 rpm
# Warning: there is ambiguity in the definition of stirring_time.
# Its current value is <None>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stirring_time
# before conversion:
# stirring_time 0.0 s
# after conversion:
# 0.0 second
# None
# ****************************************************************************************************
# Ambiguity check trial 1
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "HfOCl2.8H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.0179,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "1,3,5-Tris(4-carboxyphenyl)benzene",
#                     "H3BTB"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.0125,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "DMF"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 2.05,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "HCOOH"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.88,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.3,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "temperature": {
#             "quantity": 120.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 172800.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Precipitate",
#     "function_args": {
#         "reactor_name": "pyrex vials",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stirring_time": null,
#         "stir_speed": null,
#         "reagent": null,
#         "reagent_quantity": null,
#         "repeat": 1
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001EF9D4B4D50>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001EF9D4B5010>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001EF9D4B5190>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001EF9D4B5350>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001EF9D4B5550>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x000001EF9D4B5790>
# <llmlab.operations.exp_operation.washsolid.Precipitate object at 0x000001EF9D4B5BD0>
# ['pyrex vials']

# %%
manager.perform_exp()
# Out:
# task: AddSolid start, now time is 2024-09-21 22:20:51.518636
# task: AddSolid over, now time is 2024-09-21 22:26:41.648020
# task: AddSolid start, now time is 2024-09-21 22:26:41.648020
# task: AddSolid over, now time is 2024-09-21 22:31:45.535526
# task: AddLiquid start, now time is 2024-09-21 22:31:45.535526
# task: AddLiquid over, now time is 2024-09-21 22:35:44.544155
# task: AddLiquid start, now time is 2024-09-21 22:35:44.544155
# task: AddLiquid over, now time is 2024-09-21 22:39:35.069808
# task: AddLiquid start, now time is 2024-09-21 22:39:35.069808
# task: AddLiquid over, now time is 2024-09-21 22:43:22.648859
# task: AdjustTemperatureForDuration start, now time is 2024-09-21 22:43:22.648859
# Exception in thread COM10:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\users\admin\documents\github\platform_manager\commanduino\commanduino\commandhandler.py", line 369, in run
#     raise CMTimeout(f"Error reading from serial port {self._serial.port}! {e}") from None
# commanduino.exceptions.CMTimeout: Error reading from serial port COM10! ClearCommError failed (PermissionError(13, 'The device does not recognize the command.', None, 22))
# Exception in thread COM26:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\users\admin\documents\github\platform_manager\commanduino\commanduino\commandhandler.py", line 369, in run
#     raise CMTimeout(f"Error reading from serial port {self._serial.port}! {e}") from None
# commanduino.exceptions.CMTimeout: Error reading from serial port COM26! ClearCommError failed (PermissionError(13, 'The device does not recognize the command.', None, 22))
# Exception in thread Thread-8 (ClearRobotError):
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\users\admin\documents\github\dobot-mg400_arm\Dobot_Arms\MG400.py", line 180, in ClearRobotError
#     if  int(choose) == 1:
#         ^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: ''
# task: AdjustTemperatureForDuration over, now time is 2024-09-23 22:54:49.128181
# task: Precipitate start, now time is 2024-09-23 22:54:49.128181
# task: Precipitate over, now time is 2024-09-23 22:54:49.131180
