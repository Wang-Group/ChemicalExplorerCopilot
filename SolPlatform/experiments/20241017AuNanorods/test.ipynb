# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs20241017_1.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_22_goldnanorods_3\materials_output_20241014214553009514.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_22_goldnanorods_3\output_20241015151817653694.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['CTAB']
# after conversion:
# ['CTAB']
# before conversion:
# ['HAuCl4']
# after conversion:
# ['HAuCl4']
# before conversion:
# ['NaBH4']
# after conversion:
# ['NaBH4']
# before conversion:
# ['CTAB']
# after conversion:
# ['CTAB']
# before conversion:
# ['HAuCl4']
# after conversion:
# ['HAuCl4']
# before conversion:
# ['AA']
# after conversion:
# ['ascorbic acid', 'AA']
# before conversion:
# ['HCl']
# after conversion:
# ['hydrochloric acid', 'HCl']
# before conversion:
# ['AgNO3']
# after conversion:
# ['AgNO3']
# ####################################################################################################
# ['CTAB']
# before conversion:
# concentration 0.1 M
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 4.7 mL
# after conversion:
# 4.7 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['HAuCl4']
# before conversion:
# concentration 0.05 M
# after conversion:
# 0.05 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.025 mL
# after conversion:
# 0.025 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['NaBH4']
# before conversion:
# concentration 0.01 M
# after conversion:
# 0.01 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.3 mL
# after conversion:
# 0.3 mL
# ####################################################################################################
# Function: AddLiquid
# Property: liquid_temperature
# before conversion:
# liquid_temperature 0.0 ℃
# after conversion:
# 0.0 °C
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: StirForDuration
# Property: duration
# before conversion:
# duration 30.0 min
# after conversion:
# 1800.0 second
# ####################################################################################################
# Function: StirForDuration
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: StirForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['CTAB']
# before conversion:
# concentration 0.1 M
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 10.0 mL
# after conversion:
# 10.0 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['HAuCl4']
# before conversion:
# concentration 0.05 M
# after conversion:
# 0.05 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.1 mL
# after conversion:
# 0.1 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['ascorbic acid', 'AA']
# before conversion:
# concentration 0.1 M
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.08 mL
# after conversion:
# 0.08 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['HCl', 'hydrochloric acid']
# before conversion:
# concentration 1.0 M
# after conversion:
# 1.0 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.19 mL
# after conversion:
# 0.19 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['AgNO3']
# before conversion:
# concentration 0.01 M
# after conversion:
# 0.01 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 0.12 mL
# after conversion:
# 0.12 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: TransferLiquid
# Property: volume
# before conversion:
# volume 0.024 mL
# after conversion:
# 0.024 mL
# ####################################################################################################
# Function: TransferLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: Wait
# Property: time
# before conversion:
# time 2.0 h
# after conversion:
# 7200.0 second
# ####################################################################################################
# ['CTAB']
# before conversion:
# concentration 0.1 mol/L
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# ['NaBH4']
# before conversion:
# concentration 0.01 mol/L
# after conversion:
# 0.01 mol/L
# ####################################################################################################
# ['HAuCl4']
# before conversion:
# concentration 0.05 mol/L
# after conversion:
# 0.05 mol/L
# ####################################################################################################
# ['ascorbic acid']
# before conversion:
# concentration 0.1 mol/L
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# ['AgNO3']
# before conversion:
# concentration 0.01 mol/L
# after conversion:
# 0.01 mol/L
# ####################################################################################################
# ['hydrochloric acid']
# before conversion:
# concentration 1.0 mol/L
# after conversion:
# 1.0 mol/L
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "CTAB"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 4.7,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "HAuCl4"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.05,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.025,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "NaBH4"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.01,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.3,
#             "unit": "mL"
#         },
#         "liquid_temperature": {
#             "quantity": 0.0,
#             "unit": "\u00b0C"
#         },
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "StirForDuration",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "duration": {
#             "quantity": 1800.0,
#             "unit": "second"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_2",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "CTAB"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 10.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_2",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "HAuCl4"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.05,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.1,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_2",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "ascorbic acid",
#                     "AA"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.08,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_2",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "hydrochloric acid",
#                     "HCl"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 1.0,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.19,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_2",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "AgNO3"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.01,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.12,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "TransferLiquid",
#     "function_args": {
#         "from_reactor": "reactor_1",
#         "to_reactor": "reactor_2",
#         "volume": {
#             "quantity": 0.024,
#             "unit": "mL"
#         },
#         "dropwise": false,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Wait",
#     "function_args": {
#         "time": {
#             "quantity": 7200.0,
#             "unit": "second"
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B14810>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B14A90>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B14D50>
# <llmlab.operations.exp_operation.stir.StirForDuration object at 0x0000024EB3B14FD0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B15310>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B15450>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B15790>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B15A50>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000024EB3B15D10>
# <llmlab.operations.exp_operation.transfer.TransferLiquid object at 0x0000024EB3B16010>
# <llmlab.operations.exp_operation.wait.Wait object at 0x0000024EB3B15FD0>
# rescaling the system: rescale_factor is 0.9511128019783147
# ['reactor_1', 'reactor_2']

# %%
manager.perform_exp()
# Out:
# task: AddLiquid start, now time is 2024-10-17 12:10:01.894270
# task: AddLiquid over, now time is 2024-10-17 12:13:08.081357
# task: AddLiquid start, now time is 2024-10-17 12:13:08.081357
# task: AddLiquid over, now time is 2024-10-17 12:14:11.494938
# task: AddLiquid start, now time is 2024-10-17 12:14:11.494938
# task: AddLiquid over, now time is 2024-10-17 12:15:04.008976
# task: StirForDuration start, now time is 2024-10-17 12:15:04.008976
# task: StirForDuration over, now time is 2024-10-17 12:45:36.947056
# task: AddLiquid start, now time is 2024-10-17 12:45:36.947056
# task: AddLiquid over, now time is 2024-10-17 12:50:32.036020
# task: AddLiquid start, now time is 2024-10-17 12:50:32.036020
# task: AddLiquid over, now time is 2024-10-17 12:51:36.521724
# task: AddLiquid start, now time is 2024-10-17 12:51:36.521724
# task: AddLiquid over, now time is 2024-10-17 12:52:41.381935
# task: AddLiquid start, now time is 2024-10-17 12:52:41.381935
# task: AddLiquid over, now time is 2024-10-17 12:54:22.925331
# task: AddLiquid start, now time is 2024-10-17 12:54:22.925331
# task: AddLiquid over, now time is 2024-10-17 12:55:15.172221
# task: TrasnferLiquid start, now time is 2024-10-17 12:55:15.172221
# task: TrasnferLiquid over, now time is 2024-10-17 12:56:22.135832
# task: Wait start, now time is 2024-10-17 12:56:22.135832
# task: Wait over, now time is 2024-10-17 14:56:22.137154
