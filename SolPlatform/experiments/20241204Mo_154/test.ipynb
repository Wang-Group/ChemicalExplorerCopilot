# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs20241204.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_5_POMS\materials_output_20240730133921279423.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_5_POMS\output_20240730133921279423.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['water']
# after conversion:
# ['H2O', 'water']
# before conversion:
# ['Na2MoO4 2H2O']
# after conversion:
# ['Na2MoO4.2H2O', 'Na2MoO4 2H2O']
# before conversion:
# ['hydrochloric acid']
# after conversion:
# ['hydrochloric acid']
# before conversion:
# ['Na2S2O4']
# after conversion:
# ['Na2S2O4']
# before conversion:
# ['water']
# after conversion:
# ['H2O', 'water']
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 25.0 mL
# after conversion:
# 25.0 mL
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 3.04 g
# after conversion:
# 3.04 g
# ####################################################################################################
# ['hydrochloric acid']
# before conversion:
# concentration 32.0 %
# after conversion:
# 32.0 %
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 2.7 mL
# after conversion:
# 2.7 mL
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 0.15 g
# after conversion:
# 0.15 g
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 1.0 days
# after conversion:
# 86400.0 second
# ####################################################################################################
# Function: Filter
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: WashSolid
# Property: solvent_temperature
# before conversion:
# solvent_temperature 0.0 ℃
# after conversion:
# 0.0 °C
# ####################################################################################################
# Function: Dry
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Yield
# Property: product_quantity
# before conversion:
# product_quantity 1.15 g
# after conversion:
# 1.15 g
# ####################################################################################################
# Function: Yield
# Property: yield_percentage
# before conversion:
# yield_percentage 45.0 %
# after conversion:
# 45.0 %
# ####################################################################################################
# ['hydrochloric acid']
# before conversion:
# concentration 32.0 %
# after conversion:
# 32.0 %
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 25.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2MoO4.2H2O",
#                     "Na2MoO4 2H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 3.04,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": null
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 0.0 rpm
# after conversion:
# 0.0 rpm
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "hydrochloric acid"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 32.0,
#                 "unit": "%"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 2.7,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2S2O4"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.15,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": null
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 0.0 rpm
# after conversion:
# 0.0 rpm
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 86400.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "target_form": "solid",
#         "filtrate_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "WashSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solvent": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "solvent_temperature": {
#             "quantity": 0.0,
#             "unit": "\u00b0C"
#         },
#         "volume": "small amount",
#         "waste_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "atmosphere": "air",
#         "repeat": 1
#     }
# }
# Warning: there is ambiguity in the definition of volume.
# Its current value is <small amount>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# volume
# before conversion:
# volume 2.0 mL
# after conversion:
# 2.0 mL
# None
# ####################################################################################################
# {
#     "function_name": "Dry",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "time": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# Warning: there is ambiguity in the definition of time.
# Its current value is <None>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# time
# before conversion:
# time 10.0 min
# after conversion:
# 600.0 second
# None
# ####################################################################################################
# {
#     "function_name": "Yield",
#     "function_args": {
#         "product_name": "blue precipitated crystals",
#         "product_quantity": {
#             "quantity": 1.15,
#             "unit": "g"
#         },
#         "yield_percentage": {
#             "quantity": 45.0,
#             "unit": "%"
#         }
#     }
# }
# None
# ****************************************************************************************************
# Ambiguity check trial 1
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 25.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2MoO4.2H2O",
#                     "Na2MoO4 2H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 3.04,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "hydrochloric acid"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 32.0,
#                 "unit": "%"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 2.7,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2S2O4"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.15,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 86400.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "target_form": "solid",
#         "filtrate_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "WashSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solvent": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "solvent_temperature": {
#             "quantity": 0.0,
#             "unit": "\u00b0C"
#         },
#         "volume": "small amount",
#         "waste_vessel": "waste",
#         "stir": false,
#         "stir_speed": null,
#         "atmosphere": "air",
#         "repeat": 1
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Dry",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "time": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Yield",
#     "function_args": {
#         "product_name": "blue precipitated crystals",
#         "product_quantity": {
#             "quantity": 1.15,
#             "unit": "g"
#         },
#         "yield_percentage": {
#             "quantity": 45.0,
#             "unit": "%"
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000020C796C0550>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x0000020C796C1010>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x0000020C796C1990>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x0000020C796C1510>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x0000020C796C1790>
# <llmlab.operations.exp_operation.filtration.Filter object at 0x0000020C796C1C10>
# <llmlab.operations.exp_operation.washsolid.WashSolid object at 0x0000020C796C1D10>
# <llmlab.operations.exp_operation.washsolid.Dry object at 0x0000020C796C1B90>
# <llmlab.operations.exp_operation.yield_.Yield object at 0x0000020C796C1FD0>
# rescaling the system: rescale_factor is 0.36101083032490977
# ['reactor_1', 'waste']

# %%
manager.perform_exp()
# Out:
# task: AddLiquid start, now time is 2024-12-04 20:28:56.899397
# task: AddLiquid over, now time is 2024-12-04 20:33:58.234014
# task: AddSolid start, now time is 2024-12-04 20:33:58.234014
# task: AddSolid over, now time is 2024-12-04 20:50:26.920986
# task: AddLiquid start, now time is 2024-12-04 20:50:26.920986
# task: AddLiquid over, now time is 2024-12-04 20:51:34.522656
# task: AddSolid start, now time is 2024-12-04 20:51:34.522656
# task: AddSolid over, now time is 2024-12-04 21:08:38.224633
# task: AdjustTemperatureForDuration start, now time is 2024-12-04 21:08:38.224633
# task: AdjustTemperatureForDuration over, now time is 2024-12-05 21:08:46.292910
# task: Filter start, now time is 2024-12-05 21:08:46.296910
# task: Filter over, now time is 2024-12-05 22:13:11.093698
# task: WashSolid start, now time is 2024-12-05 22:13:11.093698
# task: WashSolid over, now time is 2024-12-05 22:44:57.796291
# task: Dry start, now time is 2024-12-05 22:44:57.796291
# task: Dry over, now time is 2024-12-05 22:54:57.797274
