# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs20250117.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_28_PMo_Poms_fix\materials_output_20241221225639398681.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_28_PMo_Poms_fix\output_20241221225639398681.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['Na2MoO4·2H2O']
# after conversion:
# ['Na2MoO4.2H2O', 'Na2MoO4·2H2O']
# before conversion:
# ['distilled water']
# after conversion:
# ['H2O', 'distilled water']
# before conversion:
# ['sodium dihydrogen phosphate']
# after conversion:
# ['sodium dihydrogen phosphate']
# before conversion:
# ['copper(II) chloride']
# after conversion:
# ['CuCl2', 'copper(II) chloride']
# before conversion:
# ['ethylenediamine']
# after conversion:
# ['ethylenediamine']
# before conversion:
# ['HCl']
# after conversion:
# ['hydrochloric acid', 'HCl']
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 2.42 g
# after conversion:
# 2.42 g
# ####################################################################################################
# Function: AddSolid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 35.0 mL
# after conversion:
# 35.0 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['sodium dihydrogen phosphate']
# before conversion:
# concentration 0.5 mol/L
# after conversion:
# 0.5 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 13.5 mL
# after conversion:
# 13.5 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['CuCl2', 'copper(II) chloride']
# before conversion:
# concentration 1.0 mol/L
# after conversion:
# 1.0 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 10.0 mL
# after conversion:
# 10.0 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['ethylenediamine']
# before conversion:
# concentration 0.3 mol/L
# after conversion:
# 0.3 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 5.0 mL
# after conversion:
# 5.0 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: AdjustpH
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# ['hydrochloric acid', 'HCl']
# before conversion:
# concentration 4.0 mol/L
# after conversion:
# 4.0 mol/L
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 85.0 ℃
# after conversion:
# 85.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 1.0 hours
# after conversion:
# 3600.0 second
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: Filter
# Property: temperature
# before conversion:
# temperature 85.0 ℃
# after conversion:
# 85.0 °C
# ####################################################################################################
# Function: AdjustTemperatureTo
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# ['ethylenediamine']
# before conversion:
# concentration 0.3 M
# after conversion:
# 0.3 mol/L
# ####################################################################################################
# ['hydrochloric acid']
# before conversion:
# concentration 4.0 M
# after conversion:
# 4.0 mol/L
# ####################################################################################################
# ['CuCl2']
# before conversion:
# concentration 1.0 M
# after conversion:
# 1.0 mol/L
# ####################################################################################################
# ['sodium dihydrogen phosphate']
# before conversion:
# concentration 0.5 M
# after conversion:
# 0.5 mol/L
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "Na2MoO4.2H2O",
#                     "Na2MoO4\u00b72H2O"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 2.42,
#             "unit": "g"
#         },
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "distilled water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 35.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "sodium dihydrogen phosphate"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.5,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 13.5,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": true
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "CuCl2",
#                     "copper(II) chloride"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 1.0,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 10.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": true
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "ethylenediamine"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.3,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 5.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": true
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustpH",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "pH": 5.5,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "acid_reagent": {
#             "identity": {
#                 "chemical_id": [
#                     "hydrochloric acid",
#                     "HCl"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 4.0,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "base_reagent": {
#             "identity": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         }
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "temperature": {
#             "quantity": 85.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 3600.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Filter",
#     "function_args": {
#         "reactor_name": "reactor1",
#         "target_form": "liquid",
#         "filtrate_vessel": "reactor2",
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 85.0,
#             "unit": "\u00b0C"
#         },
#         "atmosphere": "air"
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "reactor2",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001C2C485E5D0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001C2C485F250>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001C2C485F410>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001C2C485F6D0>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001C2C485F990>
# <llmlab.operations.exp_operation.adjustpH.AdjustpH object at 0x000001C2C485FC10>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x000001C2C48A8050>
# <llmlab.operations.exp_operation.filtration.Filter object at 0x000001C2C48A8410>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureTo object at 0x000001C2C48A8510>
# rescaling the system: rescale_factor is 0.15748031496062992
# []

# %%
manager.perform_exp()
# Out:
# task: AddSolid start, now time is 2025-01-17 10:51:30.541793
# task: AddSolid over, now time is 2025-01-17 10:58:02.119829
# task: AddLiquid start, now time is 2025-01-17 10:58:02.119829
# task: AddLiquid over, now time is 2025-01-17 11:13:39.167712
# task: AddLiquid start, now time is 2025-01-17 11:13:39.167712
# task: AddLiquid over, now time is 2025-01-17 11:16:11.887715
# task: AddLiquid start, now time is 2025-01-17 11:16:11.887715
# task: AddLiquid over, now time is 2025-01-17 11:18:06.143581
# task: AddLiquid start, now time is 2025-01-17 11:18:06.143581
# task: AddLiquid over, now time is 2025-01-17 11:19:19.827669
# task: AdjustpH start, now time is 2025-01-17 11:19:19.827669
# 6.398000000000001
# 6.321
# 6.328
# 6.253000000000001
# 6.002000000000001
# 5.645
# task: AdjustpH over, now time is 2025-01-17 11:33:06.210884
# task: AdjustTemperatureForDuration start, now time is 2025-01-17 11:33:06.210884
# task: AdjustTemperatureForDuration over, now time is 2025-01-17 12:44:38.543190
# task: Filter start, now time is 2025-01-17 12:44:38.543190
# task: Filter over, now time is 2025-01-17 14:33:55.476696
# task: AdjustTemperatureTo start, now time is 2025-01-17 14:33:55.476696
# task: AdjustTemperatureTo over, now time is 2025-01-17 14:43:55.477225
