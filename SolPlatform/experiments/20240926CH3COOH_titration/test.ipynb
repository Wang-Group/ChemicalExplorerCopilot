# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_3\materials_output_20240730133510627019.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_3\output_20240730133510627019.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
# Out:
# before conversion:
# ['acetic acid solution']
# after conversion:
# ['acetic acid', 'acetic acid solution']
# before conversion:
# ['sodium hydroxide solution']
# warning: chemical name sodium hydroxide solution does not exist in the database
# please offer a new chemical name or enter "skip" to skip!
# If enter 'skip', no molecular weight for this compound will be found.
# after conversion:
# ['NaOH']
# ####################################################################################################
# ['acetic acid', 'acetic acid solution']
# before conversion:
# concentration 0.1 M
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 5.0 mL
# after conversion:
# 5.0 mL
# ####################################################################################################
# ['NaOH']
# before conversion:
# concentration 0.1 M
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# ['acetic acid']
# before conversion:
# concentration 0.1 mol/L
# after conversion:
# 0.1 mol/L
# ####################################################################################################
# ['NaOH']
# before conversion:
# concentration 0.1 mol/L
# after conversion:
# 0.1 mol/L
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "Reactor B",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "acetic acid",
#                     "acetic acid solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 5.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustpH",
#     "function_args": {
#         "reactor_name": "Reactor B",
#         "pH": 4.5,
#         "stir": true,
#         "stir_speed": null,
#         "acid_reagent": {
#             "identity": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "base_reagent": {
#             "identity": {
#                 "chemical_id": [
#                     "NaOH"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         }
#     }
# }
# Warning: there is ambiguity in the definition of stir_speed.
# Its current value is <unknown>.
# please input a valid value to get rid of the ambiguity.
# Use -u if the input has a unit (-u 20 degrees), -f if the string is a number (-f 5.2), or -s if the input is a string (-s one string).
# ####################################################################################################
# stir_speed
# before conversion:
# stir_speed 600.0 rpm
# after conversion:
# 600.0 rpm
# None
# ****************************************************************************************************
# Ambiguity check trial 1
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "Reactor B",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "acetic acid",
#                     "acetic acid solution"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 5.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustpH",
#     "function_args": {
#         "reactor_name": "Reactor B",
#         "pH": 4.5,
#         "stir": true,
#         "stir_speed": null,
#         "acid_reagent": {
#             "identity": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "base_reagent": {
#             "identity": {
#                 "chemical_id": [
#                     "NaOH"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": 0.1,
#                 "unit": "mol/L"
#             },
#             "solvent": {
#                 "chemical_id": [
#                     "water"
#                 ],
#                 "CAS_number": []
#             }
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000002251EB8F810>
# <llmlab.operations.exp_operation.adjustpH.AdjustpH object at 0x000002251EB8FA50>
# ['Reactor B']

# %%
manager.perform_exp()
# Out:
# task: AddLiquid start, now time is 2024-09-26 17:51:51.734471
# task: AddLiquid over, now time is 2024-09-26 17:56:45.609740
# task: AdjustpH start, now time is 2024-09-26 17:56:45.609740
# 2.766
# 3.063
# 3.274
# 3.4549999999999996
# 3.5879999999999996
# 3.674000000000001
# 3.7529999999999992
# 3.8549999999999995
# 3.9189999999999996
# 3.9690000000000003
# 4.029999999999999
# 4.08
# 4.122999999999999
# 4.196
# 4.231000000000001
# 4.278999999999999
# 4.313999999999999
# 4.361
# 4.3839999999999995
# 4.4350000000000005
# task: AdjustpH over, now time is 2024-09-26 18:18:10.372283
