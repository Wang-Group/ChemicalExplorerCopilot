# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs20241201.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_25_UIO-66_fix\materials_output_20241129095856371277_copy_paste.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_25_UIO-66_fix\output_20241129095856371277_copy_paste.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
manager.mix = True
# Out:
# before conversion:
# ['ZrCl₄']
# after conversion:
# ['ZrCl4', 'ZrCl₄']
# before conversion:
# ['1,4-benzenedicarboxylic acid']
# after conversion:
# ['1,4-benzenedicarboxylic acid']
# before conversion:
# ['dimethylformamide']
# after conversion:
# ['DMF', 'dimethylformamide']
# before conversion:
# ['water']
# after conversion:
# ['H2O', 'water']
# before conversion:
# ['formic acid']
# after conversion:
# ['HCOOH', 'formic acid']
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 192.0 mg
# after conversion:
# 0.192 g
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 100.0 mg
# after conversion:
# 0.1 g
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 8.0 mL
# after conversion:
# 8.0 mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 200.0 μL
# after conversion:
# 0.2 mL
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 1.0 mL
# after conversion:
# 1.0 mL
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: temperature
# before conversion:
# temperature 120.0 °C
# after conversion:
# 120.0 °C
# ####################################################################################################
# Function: AdjustTemperatureForDuration
# Property: duration
# before conversion:
# duration 24.0 hours
# after conversion:
# 86400.0 second
# ####################################################################################################
# Function: AdjustTemperatureTo
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "20 mL reaction vial",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "ZrCl4",
#                     "ZrCl\u2084"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.192,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "20 mL reaction vial",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "1,4-benzenedicarboxylic acid"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.1,
#             "unit": "g"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "20 mL reaction vial",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "DMF",
#                     "dimethylformamide"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 8.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "20 mL reaction vial",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "H2O",
#                     "water"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 0.2,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "20 mL reaction vial",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "HCOOH",
#                     "formic acid"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 1.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": false,
#         "stir_speed": null,
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureForDuration",
#     "function_args": {
#         "reactor_name": "20 mL reaction vial",
#         "temperature": {
#             "quantity": 120.0,
#             "unit": "\u00b0C"
#         },
#         "duration": {
#             "quantity": 86400.0,
#             "unit": "second"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null,
#         "reflux": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AdjustTemperatureTo",
#     "function_args": {
#         "reactor_name": "20 mL reaction vial",
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "adjust_method": null,
#         "stir": false,
#         "stir_speed": null,
#         "ramp_rate": null
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001E63EE70E90>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001E63EE71010>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001E63EE71210>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001E63EE71350>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001E63EE71710>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureForDuration object at 0x000001E63EE71A10>
# <llmlab.operations.exp_operation.adjusttemperature.AdjustTemperatureTo object at 0x000001E63EE71E10>
# ['20 mL reaction vial']

# %%
manager.perform_exp()
# Out:
# task: AddSolid start, now time is 2024-12-01 21:52:03.968662
# task: AddSolid over, now time is 2024-12-01 21:55:57.512554
# task: AddSolid start, now time is 2024-12-01 21:55:57.512554
# task: AddSolid over, now time is 2024-12-01 21:58:28.554977
# task: AddLiquid start, now time is 2024-12-01 21:58:28.556095
# task: AddLiquid over, now time is 2024-12-01 22:13:26.540029
# task: AddLiquid start, now time is 2024-12-01 22:13:26.540029
# task: AddLiquid over, now time is 2024-12-01 22:17:59.037351
# task: AddLiquid start, now time is 2024-12-01 22:17:59.037351
# task: AddLiquid over, now time is 2024-12-01 22:18:49.332116
# task: AdjustTemperatureForDuration start, now time is 2024-12-01 22:18:49.332116
# Exception in thread Thread-7 (GetFeed):
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\users\admin\documents\github\dobot-mg400_arm\Dobot_Arms\MG400.py", line 119, in GetFeed
#     temp = self.feed.socket_dobot.recv(1440 - hasRead)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# task: AdjustTemperatureForDuration over, now time is 2024-12-02 22:30:28.716669
# task: AdjustTemperatureTo start, now time is 2024-12-02 22:30:28.718669
# task: AdjustTemperatureTo over, now time is 2024-12-02 22:40:28.721413
