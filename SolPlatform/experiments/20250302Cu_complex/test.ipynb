# %%
from solplatform import PlatformManager, LLMManager
import logging
import time
import json
from matplotlib import pyplot as plt
import numpy as np
logging.basicConfig(
    filename=f"./logs.txt",
    format="%(asctime)s %(name)-12s %(levelname)-8s %(message)s",
    level=logging.INFO,
    datefmt="%m-%d-%y %H:%M:%S",
)
logger = logging.getLogger()
platform_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//platform_config.yaml"
SS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//solid_station_mapping.json"
LS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//liquid_station_mapping.json"
FS_mapping_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//filtration_station_mapping.json"
mail_config_path = "C://Users//Admin//Documents//GitHub//platform_manager//SolPlatform//solplatform//configs//mail_config.yaml"
materials_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_11_Cu_complex\materials_output_20240910140644679817.json"
json_path = r"C:\Users\Admin\Documents\GitHub\platform_manager\SolPlatform\test\LLMTest\case_11_Cu_complex\output_20240910140644679817.json"
manager = LLMManager(
    platform_config_path,
    SS_mapping_path,
    LS_mapping_path,
    FS_mapping_path, 
    materials_path, 
    json_path, 
    mail_config_path, 
    logger=logger,
    initialize_operation=True
)

# manager.uv_vis_setup.update_integration_time(2500)

# manager = NLManager(materials_path, json_path, logger)
# Out:
# connecting
# connecting to MG400 successful!
# start enable...
# complete enable:)
# loop...

# %%
manager.check_all_procedures()
# Out:
# before conversion:
# ['[DF-CBA]Cl']
# after conversion:
# ['3,3-difluorocyclobutanamine hydrochloride', '[DF-CBA]Cl']
# before conversion:
# ['CuCl2']
# after conversion:
# ['CuCl2.2H2O', 'CuCl2']
# before conversion:
# ['methanol']
# after conversion:
# ['methanol']
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 10.0 mmol
# after conversion:
# 0.01 mol
# ####################################################################################################
# Function: AddSolid
# Property: mass
# before conversion:
# mass 5.0 mmol
# after conversion:
# 0.005 mol
# ####################################################################################################
# Function: AddLiquid
# Property: volume
# before conversion:
# volume 100.0 mL
# after conversion:
# 100.0 mL
# ####################################################################################################
# Function: AddLiquid
# Property: stir_speed
# before conversion:
# stir_speed 300.0 rpm
# after conversion:
# 300.0 rpm
# ####################################################################################################
# Function: Evaporate
# Property: temperature
# before conversion:
# temperature 20.0 ℃
# after conversion:
# 20.0 °C
# ####################################################################################################
# Function: Yield
# Property: yield_percentage
# before conversion:
# yield_percentage 98.5 %
# after conversion:
# 98.5 %
# ****************************************************************************************************
# Ambiguity check trial 0
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "3,3-difluorocyclobutanamine hydrochloride",
#                     "[DF-CBA]Cl"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.01,
#             "unit": "mol"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddSolid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "solid": {
#             "identity": {
#                 "chemical_id": [
#                     "CuCl2.2H2O",
#                     "CuCl2"
#                 ],
#                 "CAS_number": []
#             }
#         },
#         "mass": {
#             "quantity": 0.005,
#             "unit": "mol"
#         },
#         "stir": false,
#         "stir_speed": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "AddLiquid",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "liquid": {
#             "identity": {
#                 "chemical_id": [
#                     "methanol"
#                 ],
#                 "CAS_number": []
#             },
#             "concentration": {
#                 "quantity": null,
#                 "unit": null
#             },
#             "solvent": {
#                 "chemical_id": [],
#                 "CAS_number": []
#             }
#         },
#         "volume": {
#             "quantity": 100.0,
#             "unit": "mL"
#         },
#         "liquid_temperature": null,
#         "pH": null,
#         "stir": true,
#         "stir_speed": {
#             "quantity": 300.0,
#             "unit": "rpm"
#         },
#         "dropwise": false
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Evaporate",
#     "function_args": {
#         "reactor_name": "reactor_1",
#         "pressure": null,
#         "stir": false,
#         "stir_speed": null,
#         "temperature": {
#             "quantity": 20.0,
#             "unit": "\u00b0C"
#         },
#         "duration": null
#     }
# }
# None
# ####################################################################################################
# {
#     "function_name": "Yield",
#     "function_args": {
#         "product_name": "[DF-CBA]2CuCl4",
#         "product_quantity": {
#             "quantity": null,
#             "unit": null
#         },
#         "yield_percentage": {
#             "quantity": 98.5,
#             "unit": "%"
#         }
#     }
# }
# None
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001BDE3598ED0>
# <llmlab.operations.exp_operation.add.AddSolid object at 0x000001BDE3599250>
# <llmlab.operations.exp_operation.add.AddLiquid object at 0x000001BDE3599290>
# <llmlab.operations.exp_operation.evaporate.Evaporate object at 0x000001BDE3599410>
# <llmlab.operations.exp_operation.yield_.Yield object at 0x000001BDE3599810>
# rescaling the system: rescale_factor is 0.1
# ['reactor_1']

# %%
manager.perform_exp()
# Out:
# task: AddSolid start, now time is 2025-03-02 15:25:03.665279
# task: AddSolid over, now time is 2025-03-02 15:29:32.914280
# task: AddSolid start, now time is 2025-03-02 15:29:32.914280
# task: AddSolid over, now time is 2025-03-02 15:32:15.308164
# task: AddLiquid start, now time is 2025-03-02 15:32:15.308164
# task: AddLiquid over, now time is 2025-03-02 15:38:33.487456
# task: Evaporate start, now time is 2025-03-02 15:38:33.487456
# task: Evaporate over, now time is 2025-03-02 15:38:50.001888
